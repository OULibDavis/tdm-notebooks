# %% [markdown]
# <img src="https://ithaka-labs.s3.amazonaws.com/static-files/images/tdm/tdmdocs/CC_BY.png" align=left alt="CC BY license logo" /><br /><br />
# Created by [Nathan Kelber](http://nkelber.com) and Ted Lawless for [JSTOR Labs](https://labs.jstor.org/) under [Creative Commons CC BY License](https://creativecommons.org/licenses/by/4.0/)<br />
# **For questions/comments/improvements, email nathan.kelber@ithaka.org.**<br />
# ____

# %% [markdown]
# # Exploring Metadata and Pre-Processing
#
# **Description of methods in this notebook:**
# This [notebook](https://docs.constellate.org/key-terms/#jupyter-notebook) shows how to explore and pre-process the [metadata](https://docs.constellate.org/key-terms/#metadata) of a [dataset](https://docs.constellate.org/key-terms/#dataset) using [Pandas](https://docs.constellate.org/key-terms/#pandas).
#
# The following processes are described:
#
# * Importing a [CSV file](https://docs.constellate.org/key-terms/#csv-file) containing the [metadata](https://docs.constellate.org/key-terms/#metadata) for a given dataset ID
# * Creating a [Pandas](https://docs.constellate.org/key-terms/#pandas) dataframe to view the [metadata](https://docs.constellate.org/key-terms/#metadata)
# * Pre-processing your [dataset](https://docs.constellate.org/key-terms/#dataset) by filtering out unwanted texts
# * Exporting a list of relevant IDs to a [CSV file](https://docs.constellate.org/key-terms/#csv-file)
# * Visualizing the metadata of your pre-processed [dataset](https://docs.constellate.org/key-terms/#dataset) by the number of documents/year and pages/year
#
# **Use Case:** For Learners (Detailed explanation, not ideal for researchers)
#
# [Take me to the **Research Version** of this notebook ->](./exploring-metadata-for-research.ipynb)
#
# **Difficulty:** Intermediate
#
# **Completion time:** 45 minutes
#
# **Knowledge Required:**
# * Python Basics Series ([Start Python Basics 1](./python-basics-1.ipynb))
#
# **Knowledge Recommended:**
#
# * Pandas Series ([Start Pandas 1](./pandas-1.ipynb))
#
# **Data Format:** [CSV file](https://docs.constellate.org/key-terms/#csv-file)
#
# **Libraries Used:**
# * [constellate](https://docs.constellate.org/key-terms/#constellate-client) client to retrieve the [metadata](https://docs.constellate.org/key-terms/#metadata) in a [CSV file](https://docs.constellate.org/key-terms/#csv-file)
# * [pandas](https://docs.constellate.org/key-terms/#pandas) to manipulate and visualize the metadata
#
# **Research Pipeline:** None
# ____

# %% [markdown]
# ## Import your dataset
#
# We'll use the `constellate` client to automatically retrieve the [metadata](https://docs.constellate.org/key-terms/#metadata) for a [dataset](https://docs.constellate.org/key-terms/#dataset). We can retrieve [metadata](https://docs.constellate.org/key-terms/#metadata) in a [CSV file](https://docs.constellate.org/key-terms/#csv-file) using the `get_metadata` method.
#
# Enter a [dataset ID](https://docs.constellate.org/key-terms/#dataset-ID) in the next code cell.
#
# If you don't have a dataset ID, you can:
# * Use the sample dataset ID already in the code cell
# * [Create a new dataset](https://constellate.org/builder)
# * [Use a dataset ID from other pre-built sample datasets](https://constellate.org/dataset/dashboard)

# %%
# Creating a variable `dataset_id` to hold our dataset ID
# The default dataset is Shakespeare Quarterly, 1950-present
dataset_id = "7e41317e-740f-e86a-4729-20dab492e925"

# %% [markdown]
# Next, import the `constellate` client, passing the `dataset_id` as an argument using the `get_metadata` method.

# %%
# Import the `constellate` client
import constellate

# Pull in our dataset CSV using
# The .get_metadata() method downloads the CSV file for our metadata
# to the /data folder and returns a string for the file name and location
# dataset_metadata will be a string containing that file name and location
dataset_metadata = constellate.get_metadata(dataset_id)

# To download the full dataset (up to a limit of 25,000 documents),
# request it first in the builder environment. See the Constellate Client
# documentation at: https://constellate.org/docs/constellate-client
# Then use the `constellate.download` method show below.
# dataset_metadata = constellate.download(dataset_id, 'metadata')
# Out:
# Constellate: use and download of datasets is covered by the Terms & Conditions of Use: https://constellate.org/terms-and-conditions/
# All documents from JSTOR published in Shakespeare Quarterly from 1950 - 2020. 6745 documents.
# INFO:root:File /Users/laufers/data/7e41317e-740f-e86a-4729-20dab492e925-sampled-metadata.csv exists. Not re-downloading.

# %% [markdown]
# We are ready to import pandas for our analysis and create a dataframe. We will use the `read_csv()` method to create our dataframe from the CSV file.

# %%
# Import pandas 
import pandas as pd

# Create our dataframe
df = pd.read_csv(dataset_metadata)
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %% [markdown]
# We can confirm the size of our dataset using the `len()` function on our dataframe.

# %%
original_document_count = len(df)
print(f'Total original documents: {original_document_count}')
# Out:
# Total original documents: 1500

# %% [markdown]
# Now let's take a look at the data in our dataframe `df`. We will set pandas to show all columns using `set_option()` then get a preview using `head()`.

# %%
# Set the pandas option to show all columns
# Setting None gives us all columns
# To show less columns replace None with an integer
#pd.set_option("max_columns", None) 
pd.set_option("display.max_columns", None) 

# Set maximumum number of rows to 50
#pd.set_option("max_rows", 50)
pd.set_option("display.max_rows", 50)

# Show the first five rows of our dataframe
# To show a different number of preview rows
# Pass an integer into the .head()
df.head()
# Out:
#                                      id  \
# 0   http://www.jstor.org/stable/2902131
# 1   http://www.jstor.org/stable/2871217
# 2   http://www.jstor.org/stable/2866912
# 3  http://www.jstor.org/stable/41819770
# 4   http://www.jstor.org/stable/2868793
#
#                                                title               isPartOf  \
# 0   Fragments of Nationalism in Troilus and Cressida  Shakespeare Quarterly
# 1  Shakespearean Chronology, Ideological Complici...  Shakespeare Quarterly
# 2                                     Review Article  Shakespeare Quarterly
# 3                                     Review Article  Shakespeare Quarterly
# 4                                     Review Article  Shakespeare Quarterly
#
#    publicationYear  doi  docType provider datePublished  issueNumber  \
# 0             2000  NaN  article    jstor    2000-07-01          2.0
# 1             1994  NaN  article    jstor    1994-07-01          2.0
# 2             1962  NaN  article    jstor    1962-01-01          1.0
# 3             2012  NaN  article    jstor    2012-12-01          4.0
# 4             1974  NaN  article    jstor    1974-07-01          3.0
#
#    volumeNumber                                   url                creator  \
# 0            51   http://www.jstor.org/stable/2902131  Matthew A. Greenfield
# 1            45   http://www.jstor.org/stable/2871217       Barbara Freedman
# 2            13   http://www.jstor.org/stable/2866912              R. G. Cox
# 3            63  http://www.jstor.org/stable/41819770           Darryl Gless
# 4            25   http://www.jstor.org/stable/2868793        Marion O'Connor
#
#                     publisher language pageStart pageEnd  placeOfPublication  \
# 0  Folger Shakespeare Library      eng       181     200                 NaN
# 1  Folger Shakespeare Library      eng       190     210                 NaN
# 2  Folger Shakespeare Library      eng        96      97                 NaN
# 3  Folger Shakespeare Library      eng       580     587                 NaN
# 4  Folger Shakespeare Library      eng       370     373                 NaN
#
#    wordCount  pageCount              outputFormat
# 0       9538         20  unigram; bigram; trigram
# 1      12472         21  unigram; bigram; trigram
# 2        573          2  unigram; bigram; trigram
# 3       3658          8  unigram; bigram; trigram
# 4       1914          4  unigram; bigram; trigram

# %% [markdown]
# Here are descriptions for the metadata types found in each column:
#
# |Column Name|Description|
# |---|---|
# |id|a unique item ID (In JSTOR, this is a stable URL)|
# |title|the title for the item|
# |isPartOf|the larger work that holds this title (for example, a journal title)|
# |publicationYear|the year of publication|
# |doi|the digital object identifier for an item|
# |docType|the type of document (for example, article or book)|
# |provider|the source or provider of the dataset|
# |datePublished|the publication date in yyyy-mm-dd format|
# |issueNumber|the issue number for a journal publication|
# |volumeNumber|the volume number for a journal publication|
# |url|a URL for the item and/or the item's metadata|
# |creator|the author or authors of the item|
# |publisher|the publisher for the item|
# |language|the language or languages of the item (eng is the ISO 639 code for English)|
# |pageStart|the first page number of the print version|
# |pageEnd|the last page number of the print version|
# |placeOfPublication|the city of the publisher|
# |wordCount|the number of words in the item|
# |pageCount|the number of print pages in the item|
# |outputFormat|what data is available ([unigrams](https://docs.constellate.org/key-terms/#unigram), [bigrams](https://docs.constellate.org/key-terms/#bigram), [trigrams](https://docs.constellate.org/key-terms/#trigram), and/or full-text)|
#
# ___

# %% [markdown]
# ## Filtering out columns using Pandas
#
# If there are any columns you would like to drop from your analysis, you can drop them with:
#
# `df = df.drop(['column_name1', 'column_name2', ...], axis=1)`

# %%
# Drop each of these named columns
# axis=1 specifies we are dropping columns
# axis=0 would specify to drop rows
df = df.drop(['outputFormat', 'pageEnd', 'pageStart', 'datePublished'], axis=1)

# Show the first five rows of our updated dataframe
df.head()
# Out:
#                                      id  \
# 0   http://www.jstor.org/stable/2902131
# 1   http://www.jstor.org/stable/2871217
# 2   http://www.jstor.org/stable/2866912
# 3  http://www.jstor.org/stable/41819770
# 4   http://www.jstor.org/stable/2868793
#
#                                                title               isPartOf  \
# 0   Fragments of Nationalism in Troilus and Cressida  Shakespeare Quarterly
# 1  Shakespearean Chronology, Ideological Complici...  Shakespeare Quarterly
# 2                                     Review Article  Shakespeare Quarterly
# 3                                     Review Article  Shakespeare Quarterly
# 4                                     Review Article  Shakespeare Quarterly
#
#    publicationYear  doi  docType provider  issueNumber  volumeNumber  \
# 0             2000  NaN  article    jstor          2.0            51
# 1             1994  NaN  article    jstor          2.0            45
# 2             1962  NaN  article    jstor          1.0            13
# 3             2012  NaN  article    jstor          4.0            63
# 4             1974  NaN  article    jstor          3.0            25
#
#                                     url                creator  \
# 0   http://www.jstor.org/stable/2902131  Matthew A. Greenfield
# 1   http://www.jstor.org/stable/2871217       Barbara Freedman
# 2   http://www.jstor.org/stable/2866912              R. G. Cox
# 3  http://www.jstor.org/stable/41819770           Darryl Gless
# 4   http://www.jstor.org/stable/2868793        Marion O'Connor
#
#                     publisher language  placeOfPublication  wordCount  \
# 0  Folger Shakespeare Library      eng                 NaN       9538
# 1  Folger Shakespeare Library      eng                 NaN      12472
# 2  Folger Shakespeare Library      eng                 NaN        573
# 3  Folger Shakespeare Library      eng                 NaN       3658
# 4  Folger Shakespeare Library      eng                 NaN       1914
#
#    pageCount
# 0         20
# 1         21
# 2          2
# 3          8
# 4          4

# %% [markdown]
# ## Filtering out rows with Pandas
#
# Now that we have filtered out unwanted metadata columns, we can begin filtering out any texts that may not match our research interests. Let's examine the first and last ten rows of the dataframe to see if we can identify texts that we would like to remove. We are looking for patterns in the metadata that could help us remove many texts at once.

# %%
# Preview the first ten items in the dataframe
# Can you identify patterns to select rows to remove?
df.head(10)
# Out:
#                                      id  \
# 0   http://www.jstor.org/stable/2902131
# 1   http://www.jstor.org/stable/2871217
# 2   http://www.jstor.org/stable/2866912
# 3  http://www.jstor.org/stable/41819770
# 4   http://www.jstor.org/stable/2868793
# 5   http://www.jstor.org/stable/2869261
# 6   http://www.jstor.org/stable/2870776
# 7   http://www.jstor.org/stable/2869933
# 8   http://www.jstor.org/stable/2866221
# 9   http://www.jstor.org/stable/2870918
#
#                                                title               isPartOf  \
# 0   Fragments of Nationalism in Troilus and Cressida  Shakespeare Quarterly
# 1  Shakespearean Chronology, Ideological Complici...  Shakespeare Quarterly
# 2                                     Review Article  Shakespeare Quarterly
# 3                                     Review Article  Shakespeare Quarterly
# 4                                     Review Article  Shakespeare Quarterly
# 5     Falstaff in Windsor Forest: Villain or Victim?  Shakespeare Quarterly
# 6         Coriolanus: Body Politic and Private Parts  Shakespeare Quarterly
# 7                  Shakespeare in West Germany, 1983  Shakespeare Quarterly
# 8                                     Review Article  Shakespeare Quarterly
# 9                                     Review Article  Shakespeare Quarterly
#
#    publicationYear  doi  docType provider  issueNumber  volumeNumber  \
# 0             2000  NaN  article    jstor          2.0            51
# 1             1994  NaN  article    jstor          2.0            45
# 2             1962  NaN  article    jstor          1.0            13
# 3             2012  NaN  article    jstor          4.0            63
# 4             1974  NaN  article    jstor          3.0            25
# 5             1975  NaN  article    jstor          1.0            26
# 6             1990  NaN  article    jstor          4.0            41
# 7             1984  NaN  article    jstor          2.0            35
# 8             1951  NaN  article    jstor          2.0             2
# 9             1992  NaN  article    jstor          1.0            43
#
#                                     url                 creator  \
# 0   http://www.jstor.org/stable/2902131   Matthew A. Greenfield
# 1   http://www.jstor.org/stable/2871217        Barbara Freedman
# 2   http://www.jstor.org/stable/2866912               R. G. Cox
# 3  http://www.jstor.org/stable/41819770            Darryl Gless
# 4   http://www.jstor.org/stable/2868793         Marion O'Connor
# 5   http://www.jstor.org/stable/2869261  Jeanne Addison Roberts
# 6   http://www.jstor.org/stable/2870776           Zvi Jagendorf
# 7   http://www.jstor.org/stable/2869933        Wilhelm Hortmann
# 8   http://www.jstor.org/stable/2866221      A. H. R. Fairchild
# 9   http://www.jstor.org/stable/2870918            John W. Velz
#
#                     publisher language  placeOfPublication  wordCount  \
# 0  Folger Shakespeare Library      eng                 NaN       9538
# 1  Folger Shakespeare Library      eng                 NaN      12472
# 2  Folger Shakespeare Library      eng                 NaN        573
# 3  Folger Shakespeare Library      eng                 NaN       3658
# 4  Folger Shakespeare Library      eng                 NaN       1914
# 5  Folger Shakespeare Library      eng                 NaN       4193
# 6  Folger Shakespeare Library      eng                 NaN       8209
# 7  Folger Shakespeare Library      eng                 NaN       2764
# 8  Folger Shakespeare Library      eng                 NaN       1207
# 9  Folger Shakespeare Library      eng                 NaN       1517
#
#    pageCount
# 0         20
# 1         21
# 2          2
# 3          8
# 4          4
# 5          8
# 6         15
# 7          5
# 8          2
# 9          3

# %%
# Preview the last ten items in the dataframe
# Can you identify patterns to select rows to remove?
df.tail(10)
# Out:
#                                         id                          title  \
# 1490  http://www.jstor.org/stable/41679774                 Review Article
# 1491   http://www.jstor.org/stable/2868044                 Review Article
# 1492   http://www.jstor.org/stable/2870754  They Were Not Such Good Years
# 1493   http://www.jstor.org/stable/2868513  The Third Murderer in Macbeth
# 1494   http://www.jstor.org/stable/2871404                 Review Article
# 1495   http://www.jstor.org/stable/2869482       The New Arden Coriolanus
# 1496   http://www.jstor.org/stable/2867034                 Review Article
# 1497   http://www.jstor.org/stable/2871079                            [H]
# 1498   http://www.jstor.org/stable/2868190                 Review Article
# 1499   http://www.jstor.org/stable/2866411                 Review Article
#
#                    isPartOf  publicationYear  doi  docType provider  \
# 1490  Shakespeare Quarterly             2012  NaN  article    jstor
# 1491  Shakespeare Quarterly             1962  NaN  article    jstor
# 1492  Shakespeare Quarterly             1989  NaN  article    jstor
# 1493  Shakespeare Quarterly             1972  NaN  article    jstor
# 1494  Shakespeare Quarterly             1997  NaN  article    jstor
# 1495  Shakespeare Quarterly             1979  NaN  article    jstor
# 1496  Shakespeare Quarterly             1959  NaN  article    jstor
# 1497  Shakespeare Quarterly             1964  NaN  article    jstor
# 1498  Shakespeare Quarterly             1963  NaN  article    jstor
# 1499  Shakespeare Quarterly             1955  NaN  article    jstor
#
#       issueNumber  volumeNumber                                   url  \
# 1490          3.0            63  http://www.jstor.org/stable/41679774
# 1491          NaN             4   http://www.jstor.org/stable/2868044
# 1492          1.0            40   http://www.jstor.org/stable/2870754
# 1493          3.0            23   http://www.jstor.org/stable/2868513
# 1494          1.0            48   http://www.jstor.org/stable/2871404
# 1495          3.0            30   http://www.jstor.org/stable/2869482
# 1496          1.0            10   http://www.jstor.org/stable/2867034
# 1497          NaN            15   http://www.jstor.org/stable/2871079
# 1498          4.0            14   http://www.jstor.org/stable/2868190
# 1499          2.0             6   http://www.jstor.org/stable/2866411
#
#                      creator                   publisher language  \
# 1490             David Riggs  Folger Shakespeare Library      eng
# 1491   George Burke Johnston  Folger Shakespeare Library      eng
# 1492      Frankie Rubinstein  Folger Shakespeare Library      eng
# 1493  George Walton Williams  Folger Shakespeare Library      eng
# 1494       M. Lindsay Kaplan  Folger Shakespeare Library      eng
# 1495       T. H. Howard-Hill  Folger Shakespeare Library      eng
# 1496           Yar Slavutych  Folger Shakespeare Library      eng
# 1497                     NaN  Folger Shakespeare Library      eng
# 1498            Thomas Pyles  Folger Shakespeare Library      eng
# 1499               S. Thomas  Folger Shakespeare Library      eng
#
#       placeOfPublication  wordCount  pageCount
# 1490                 NaN       1577          4
# 1491                 NaN        498          1
# 1492                 NaN       3686          5
# 1493                 NaN        274          1
# 1494                 NaN       1011          2
# 1495                 NaN       2064          4
# 1496                 NaN        981          2
# 1497                 NaN      13450         25
# 1498                 NaN        573          2
# 1499                 NaN        242          1

# %%
# We create a function to report how many documents were removed.

def texts_report(pre_count):
    """Prints out a report of:
    1. How many documents were removed
    2. The total original number of documents
    3. The total current number of documents
    """
    
    removed_count = pre_count - len(df)
    print(f'{removed_count} texts were removed.')
    print(f'Total original documents: {original_document_count}')
    print('Total current documents: ', len(df))

# %% [markdown]
# ### Remove all rows without data for a particular column
#
# For example, we may wish to remove any texts that do not have authors. (In the case of journals, this may be helpful for removing paratextual sections such as the table of contents, indices, etc.) The column of interest in this case is `creator`.

# %%
# Remove all texts without an author

print('Removing texts without authors...')
initial_count = len(df)
df = df.dropna(subset=['creator']) #drop each row that has no value under 'creators'

# Report the number of texts removed
texts_report(initial_count)
# Out:
# Removing texts without authors...
# 291 texts were removed.
# Total original documents: 1500
# Total current documents:  1209

# %% [markdown]
# ### Remove row based on the content of a particular column
#
# We can also remove texts, depending on whether we do (or do not) want a particular value in a column. Here are a few examples.

# %%
# Remove all items with a particular title
# Change title to desired column
# Change `Review Article` to your undesired title
title_to_remove = 'Review Article'

# Removing texts
print(f'Removing texts with title "{title_to_remove}"...')
initial_count = len(df)

# Create a filter that returns all titles that do not match `title_to_remove`
# Apply the filter to the DataFrame
title_filter = df['title'] != title_to_remove
df = df[title_filter]

# Report the number of texts removed
texts_report(initial_count)
# Out:
# Removing texts with title "Review Article"...
# 508 texts were removed.
# Total original documents: 1500
# Total current documents:  701

# %%
# Keep only items with a particular language
# Change language to desired column
# Change 'eng' to your desired language
language = 'eng' # Change to another language code for other languages

# Removing texts
print(f'Removing texts not in "{language}" language...')
initial_count = len(df)

# Create a filter that returns all languages matching `language` variable
language_filter = df['language'] == language
df = df[language_filter] # Apply filter to the DataFrame

# Report the number of texts removed
texts_report(initial_count)
# Out:
# Removing texts not in "eng" language...
# 0 texts were removed.
# Total original documents: 1500
# Total current documents:  701

# %%
# Remove all items with less than 1500 words
# Change `min_word_count to your desired minimum number of words
min_word_count = 1500

# Removing texts
print(f'Removing texts with fewer than {min_word_count} words...')
initial_count = len(df)

# Create a filter that 
word_count_filter = df['wordCount'] > min_word_count
df = df[word_count_filter]

# Report the number of texts removed
texts_report(initial_count)
# Out:
# Removing texts with fewer than 1500 words...
# 177 texts were removed.
# Total original documents: 1500
# Total current documents:  524

# %% [markdown]
# Take a final look at your dataframe to make sure the current texts fit your research goals. In the next step, we will save the IDs of your pre-processed dataset.

# %%
# Preview the first 50 rows of your dataset
# If all the items look good, move to the next step.
df.head(50)
# Out:
#                                        id  \
# 0     http://www.jstor.org/stable/2902131
# 1     http://www.jstor.org/stable/2871217
# 5     http://www.jstor.org/stable/2869261
# 6     http://www.jstor.org/stable/2870776
# 7     http://www.jstor.org/stable/2869933
# 12    http://www.jstor.org/stable/2871118
# 14    http://www.jstor.org/stable/2867722
# 15    http://www.jstor.org/stable/4624955
# 23    http://www.jstor.org/stable/2867738
# 29    http://www.jstor.org/stable/2868912
# 31   http://www.jstor.org/stable/40210320
# 38    http://www.jstor.org/stable/2868654
# 40    http://www.jstor.org/stable/3844120
# 45    http://www.jstor.org/stable/2868209
# 47    http://www.jstor.org/stable/2870611
# 50    http://www.jstor.org/stable/2868884
# 54    http://www.jstor.org/stable/2869319
# 56   http://www.jstor.org/stable/41679770
# 57    http://www.jstor.org/stable/2868959
# 58    http://www.jstor.org/stable/2867098
# 59    http://www.jstor.org/stable/2868281
# 60    http://www.jstor.org/stable/2867117
# 71    http://www.jstor.org/stable/2868655
# 74    http://www.jstor.org/stable/3648670
# 75    http://www.jstor.org/stable/2866523
# 79    http://www.jstor.org/stable/2867969
# 86    http://www.jstor.org/stable/2869640
# 87    http://www.jstor.org/stable/2868241
# 88    http://www.jstor.org/stable/2869865
# 90    http://www.jstor.org/stable/3844266
# 92    http://www.jstor.org/stable/2870827
# 93    http://www.jstor.org/stable/2871120
# 94    http://www.jstor.org/stable/2868094
# 98    http://www.jstor.org/stable/2869211
# 101   http://www.jstor.org/stable/2902205
# 108   http://www.jstor.org/stable/2866250
# 116   http://www.jstor.org/stable/2867260
# 118  http://www.jstor.org/stable/44990247
# 120   http://www.jstor.org/stable/2870564
# 121   http://www.jstor.org/stable/2868638
# 122   http://www.jstor.org/stable/2870087
# 127   http://www.jstor.org/stable/2868262
# 128   http://www.jstor.org/stable/2866785
# 130   http://www.jstor.org/stable/2866616
# 138   http://www.jstor.org/stable/2871139
# 139   http://www.jstor.org/stable/2866588
# 140   http://www.jstor.org/stable/2870953
# 143   http://www.jstor.org/stable/2867894
# 144   http://www.jstor.org/stable/2866475
# 145   http://www.jstor.org/stable/2866423
#
#                                                  title               isPartOf  \
# 0     Fragments of Nationalism in Troilus and Cressida  Shakespeare Quarterly
# 1    Shakespearean Chronology, Ideological Complici...  Shakespeare Quarterly
# 5       Falstaff in Windsor Forest: Villain or Victim?  Shakespeare Quarterly
# 6           Coriolanus: Body Politic and Private Parts  Shakespeare Quarterly
# 7                    Shakespeare in West Germany, 1983  Shakespeare Quarterly
# 12   Love as Trompe-l'oeil: Taxonomies of Desire in...  Shakespeare Quarterly
# 14   Reviews of Books Previously Recorded in Shakes...  Shakespeare Quarterly
# 15   Citizens' Games: Differentiating Collaboration...  Shakespeare Quarterly
# 23              Shakespeare In the Seventeenth Century  Shakespeare Quarterly
# 29             Shakespeare at Stratford, Ontario, 1971  Shakespeare Quarterly
# 31   The Alcestis and the Statue Scene in the Winte...  Shakespeare Quarterly
# 38        Shakespeare, the Ancients, and Hales of Eton  Shakespeare Quarterly
# 40   When Theaters Were Bear-Gardens; Or, What's at...  Shakespeare Quarterly
# 45                                 The Unknown Ulysses  Shakespeare Quarterly
# 47   Prince Hal's Falstaff: Positioning Psychoanaly...  Shakespeare Quarterly
# 50     All's Well That Ends Well and the Morality Play  Shakespeare Quarterly
# 54                       Oregon Shakespearean Festival  Shakespeare Quarterly
# 56   Pageantry, Queens, and Housewives in the Two T...  Shakespeare Quarterly
# 57                                            Articles  Shakespeare Quarterly
# 58   King Lear: A Study in Balanced and Shifting Sy...  Shakespeare Quarterly
# 59                  A Test for "Accomplished Scholars"  Shakespeare Quarterly
# 60         London's New Mermaid Theatre at Puddle Dock  Shakespeare Quarterly
# 71       The Psyche Myth and A Midsummer Night's Dream  Shakespeare Quarterly
# 74                           "Cymbeline" at Santa Cruz  Shakespeare Quarterly
# 75         The Authenticity of The Taming of the Shrew  Shakespeare Quarterly
# 79                       "He That did the Tiger Board"  Shakespeare Quarterly
# 86   The Winter's Tale, II. iii. 103-7: An Allusion...  Shakespeare Quarterly
# 87                    "What is the Matter?" in Othello  Shakespeare Quarterly
# 88                              Shakespeare in Ireland  Shakespeare Quarterly
# 90       John Shakespeare: A Papist or Just Penniless?  Shakespeare Quarterly
# 92      The Colorado Shakespeare Festival, Summer 1987  Shakespeare Quarterly
# 93   The Masculine Romance of Roman Britain: Cymbel...  Shakespeare Quarterly
# 94   The Shakespearian Clock: Time and the Vision o...  Shakespeare Quarterly
# 98                              Shakespeare in Romania  Shakespeare Quarterly
# 101                          Shakespeare and Lancaster  Shakespeare Quarterly
# 108           Language Lesson Dialogues in Shakespeare  Shakespeare Quarterly
# 116            Collections, Editions, and Translations  Shakespeare Quarterly
# 118  Bibliography: Shakespeare: Annotated World Bib...  Shakespeare Quarterly
# 120  Julio Cesar, et al.: The 1986 Florida Shakespe...  Shakespeare Quarterly
# 121                                      Dissertations  Shakespeare Quarterly
# 122                          Stratford Festival Canada  Shakespeare Quarterly
# 127         The Tempest: Rebellion and the Ideal State  Shakespeare Quarterly
# 128    King Lear: Moral Example or Tragic Protagonist?  Shakespeare Quarterly
# 130                       The Problem of Julius Caesar  Shakespeare Quarterly
# 138   Shylock, Robert Miles, and Events at the Theatre  Shakespeare Quarterly
# 139                      A Shakespeare Haunt in Bucks?  Shakespeare Quarterly
# 140  Judith Shakespeare's Reading: Teaching The Con...  Shakespeare Quarterly
# 143                                    Hamlet's Mother  Shakespeare Quarterly
# 144                           The Cunning of the Scene  Shakespeare Quarterly
# 145                            The Over Garrulous Iago  Shakespeare Quarterly
#
#      publicationYear  doi  docType provider  issueNumber  volumeNumber  \
# 0               2000  NaN  article    jstor          2.0            51
# 1               1994  NaN  article    jstor          2.0            45
# 5               1975  NaN  article    jstor          1.0            26
# 6               1990  NaN  article    jstor          4.0            41
# 7               1984  NaN  article    jstor          2.0            35
# 12              1995  NaN  article    jstor          3.0            46
# 14              1966  NaN  article    jstor          3.0            17
# 15              2007  NaN  article    jstor          1.0            58
# 23              1965  NaN  article    jstor          1.0            16
# 29              1971  NaN  article    jstor          4.0            22
# 31              2009  NaN  article    jstor          1.0            60
# 38              1972  NaN  article    jstor          1.0            23
# 40              2003  NaN  article    jstor          1.0            54
# 45              1968  NaN  article    jstor          2.0            19
# 47              1989  NaN  article    jstor          4.0            40
# 50              1974  NaN  article    jstor          1.0            25
# 54              1979  NaN  article    jstor          2.0            30
# 56              2012  NaN  article    jstor          3.0            63
# 57              1974  NaN  article    jstor          4.0            25
# 58              1959  NaN  article    jstor          4.0            10
# 59              1965  NaN  article    jstor          2.0            16
# 60              1959  NaN  article    jstor          4.0            10
# 71              1972  NaN  article    jstor          1.0            23
# 74              2001  NaN  article    jstor          2.0            52
# 75              1954  NaN  article    jstor          1.0             5
# 79              1964  NaN  article    jstor          1.0            15
# 86              1977  NaN  article    jstor          1.0            28
# 87              1966  NaN  article    jstor          2.0            17
# 88              1983  NaN  article    jstor          4.0            34
# 90              2005  NaN  article    jstor          4.0            56
# 92              1989  NaN  article    jstor          2.0            40
# 93              1995  NaN  article    jstor          3.0            46
# 94              1964  NaN  article    jstor          4.0            15
# 98              1980  NaN  article    jstor          3.0            31
# 101             1998  NaN  article    jstor          1.0            49
# 108             1951  NaN  article    jstor          4.0             2
# 116             1958  NaN  article    jstor          2.0             9
# 118             1989  NaN  article    jstor          5.0            40
# 120             1987  NaN  article    jstor          2.0            38
# 121             1973  NaN  article    jstor          4.0            24
# 122             1985  NaN  article    jstor          1.0            36
# 127             1965  NaN  article    jstor          2.0            16
# 128             1962  NaN  article    jstor          2.0            13
# 130             1955  NaN  article    jstor          3.0             6
# 138             1993  NaN  article    jstor          2.0            44
# 139             1954  NaN  article    jstor          2.0             5
# 140             1996  NaN  article    jstor          4.0            47
# 143             1964  NaN  article    jstor          2.0            15
# 144             1953  NaN  article    jstor          4.0             4
# 145             1950  NaN  article    jstor          3.0             1
#
#                                       url  \
# 0     http://www.jstor.org/stable/2902131
# 1     http://www.jstor.org/stable/2871217
# 5     http://www.jstor.org/stable/2869261
# 6     http://www.jstor.org/stable/2870776
# 7     http://www.jstor.org/stable/2869933
# 12    http://www.jstor.org/stable/2871118
# 14    http://www.jstor.org/stable/2867722
# 15    http://www.jstor.org/stable/4624955
# 23    http://www.jstor.org/stable/2867738
# 29    http://www.jstor.org/stable/2868912
# 31   http://www.jstor.org/stable/40210320
# 38    http://www.jstor.org/stable/2868654
# 40    http://www.jstor.org/stable/3844120
# 45    http://www.jstor.org/stable/2868209
# 47    http://www.jstor.org/stable/2870611
# 50    http://www.jstor.org/stable/2868884
# 54    http://www.jstor.org/stable/2869319
# 56   http://www.jstor.org/stable/41679770
# 57    http://www.jstor.org/stable/2868959
# 58    http://www.jstor.org/stable/2867098
# 59    http://www.jstor.org/stable/2868281
# 60    http://www.jstor.org/stable/2867117
# 71    http://www.jstor.org/stable/2868655
# 74    http://www.jstor.org/stable/3648670
# 75    http://www.jstor.org/stable/2866523
# 79    http://www.jstor.org/stable/2867969
# 86    http://www.jstor.org/stable/2869640
# 87    http://www.jstor.org/stable/2868241
# 88    http://www.jstor.org/stable/2869865
# 90    http://www.jstor.org/stable/3844266
# 92    http://www.jstor.org/stable/2870827
# 93    http://www.jstor.org/stable/2871120
# 94    http://www.jstor.org/stable/2868094
# 98    http://www.jstor.org/stable/2869211
# 101   http://www.jstor.org/stable/2902205
# 108   http://www.jstor.org/stable/2866250
# 116   http://www.jstor.org/stable/2867260
# 118  http://www.jstor.org/stable/44990247
# 120   http://www.jstor.org/stable/2870564
# 121   http://www.jstor.org/stable/2868638
# 122   http://www.jstor.org/stable/2870087
# 127   http://www.jstor.org/stable/2868262
# 128   http://www.jstor.org/stable/2866785
# 130   http://www.jstor.org/stable/2866616
# 138   http://www.jstor.org/stable/2871139
# 139   http://www.jstor.org/stable/2866588
# 140   http://www.jstor.org/stable/2870953
# 143   http://www.jstor.org/stable/2867894
# 144   http://www.jstor.org/stable/2866475
# 145   http://www.jstor.org/stable/2866423
#
#                                                creator  \
# 0                                Matthew A. Greenfield
# 1                                     Barbara Freedman
# 5                               Jeanne Addison Roberts
# 6                                        Zvi Jagendorf
# 7                                     Wilhelm Hortmann
# 12                                    Catherine Belsey
# 14                                Rudolph E. Habenicht
# 15                                         Nina Levine
# 23                                         David Frost
# 29                                  Berners W. Jackson
# 31                                  Sarah Dewar-Watson
# 38                                      John Freehafer
# 40                                  Jason Scott-Warren
# 45                                    Karl F. Thompson
# 47                                       Valerie Traub
# 50                                      W. L. Godshalk
# 54                                      Alan C. Dessen
# 56                           Elizabeth Zeman Kolkovich
# 57                     Bruce Nesbitt; Thomas F. Grieve
# 58                                     Edward A. Block
# 59                                          R. W. Dent
# 60                                   Bernard M. Wagner
# 71                                  James A. S. McPeek
# 74                                       Stephen Orgel
# 75                                      K. Wentersdorf
# 79                                    Marion A. Taylor
# 86                                Nicolas K. Kiessling
# 87                                           John Shaw
# 88                                  Christopher Murray
# 90                                      Robert Bearman
# 92                                      Michael Mullin
# 93                                     Jodi Mikalachki
# 94                                       Tom F. Driver
# 98                                     Ileana Berlogea
# 101                                     Richard Dutton
# 108                                R. C. Simonini, Jr.
# 116                                  Paul A. Jorgensen
# 118  HARRISON T. MESEROLE; JAMES L. HARNER; PRISCIL...
# 120                                Peggy Goodman Endel
# 121                                      Bruce Nesbitt
# 122                                        Ralph Berry
# 127                                         Dean Ebner
# 128                                  Francis G. Schoff
# 130                                    Ernest Schanzer
# 138                                      Herbert Berry
# 139                                  Herbert C. Schulz
# 140                                       Lisa Hopkins
# 143                                    Baldwin Maxwell
# 144                                    Andrew J. Green
# 145                                Frank Prentice Rand
#
#                       publisher language  placeOfPublication  wordCount  \
# 0    Folger Shakespeare Library      eng                 NaN       9538
# 1    Folger Shakespeare Library      eng                 NaN      12472
# 5    Folger Shakespeare Library      eng                 NaN       4193
# 6    Folger Shakespeare Library      eng                 NaN       8209
# 7    Folger Shakespeare Library      eng                 NaN       2764
# 12   Folger Shakespeare Library      eng                 NaN      10617
# 14   Folger Shakespeare Library      eng                 NaN       6258
# 15   Folger Shakespeare Library      eng                 NaN      16625
# 23   Folger Shakespeare Library      eng                 NaN       4963
# 29   Folger Shakespeare Library      eng                 NaN       3737
# 31   Folger Shakespeare Library      eng                 NaN       3161
# 38   Folger Shakespeare Library      eng                 NaN       3184
# 40   Folger Shakespeare Library      eng                 NaN       9882
# 45   Folger Shakespeare Library      eng                 NaN       2247
# 47   Folger Shakespeare Library      eng                 NaN      10748
# 50   Folger Shakespeare Library      eng                 NaN       5069
# 54   Folger Shakespeare Library      eng                 NaN       6853
# 56   Folger Shakespeare Library      eng                 NaN      13029
# 57   Folger Shakespeare Library      eng                 NaN      17096
# 58   Folger Shakespeare Library      eng                 NaN       7148
# 59   Folger Shakespeare Library      eng                 NaN       5735
# 60   Folger Shakespeare Library      eng                 NaN       2235
# 71   Folger Shakespeare Library      eng                 NaN       6321
# 74   Folger Shakespeare Library      eng                 NaN       3762
# 75   Folger Shakespeare Library      eng                 NaN       9920
# 79   Folger Shakespeare Library      eng                 NaN       1846
# 86   Folger Shakespeare Library      eng                 NaN       1623
# 87   Folger Shakespeare Library      eng                 NaN       2362
# 88   Folger Shakespeare Library      eng                 NaN       1580
# 90   Folger Shakespeare Library      eng                 NaN      11805
# 92   Folger Shakespeare Library      eng                 NaN       2588
# 93   Folger Shakespeare Library      eng                 NaN      12816
# 94   Folger Shakespeare Library      eng                 NaN       4596
# 98   Folger Shakespeare Library      eng                 NaN       2170
# 101  Folger Shakespeare Library      eng                 NaN      12953
# 108  Folger Shakespeare Library      eng                 NaN       4975
# 116  Folger Shakespeare Library      eng                 NaN       3120
# 118     Oxford University Press      eng                 NaN     311777
# 120  Folger Shakespeare Library      eng                 NaN       2532
# 121  Folger Shakespeare Library      eng                 NaN       2836
# 122  Folger Shakespeare Library      eng                 NaN       5384
# 127  Folger Shakespeare Library      eng                 NaN       6230
# 128  Folger Shakespeare Library      eng                 NaN       9755
# 130  Folger Shakespeare Library      eng                 NaN       6113
# 138  Folger Shakespeare Library      eng                 NaN      11100
# 139  Folger Shakespeare Library      eng                 NaN       2865
# 140  Folger Shakespeare Library      eng                 NaN       5291
# 143  Folger Shakespeare Library      eng                 NaN       6280
# 144  Folger Shakespeare Library      eng                 NaN       5053
# 145  Folger Shakespeare Library      eng                 NaN       3647
#
#      pageCount
# 0           20
# 1           21
# 5            8
# 6           15
# 7            5
# 12          20
# 14          13
# 15          34
# 23           9
# 29          10
# 31           8
# 38           6
# 40          20
# 45           4
# 47          19
# 50          10
# 54          10
# 56          27
# 57          35
# 58          14
# 59           9
# 60           4
# 71          11
# 74           9
# 75          22
# 79           4
# 86           3
# 87           5
# 88           3
# 90          23
# 92           5
# 93          22
# 94           8
# 98           3
# 101         21
# 108         13
# 116          6
# 118        441
# 120          4
# 121          7
# 122          7
# 127         13
# 128         16
# 130         12
# 138         19
# 139          4
# 140         11
# 143         12
# 144         10
# 145          8

# %% [markdown]
# ## Saving a list of IDs to a CSV file

# %%
# Write the column "id" to a CSV file called `pre-processed_###.csv` where ### is the `dataset_id`
df["id"].to_csv('data/pre-processed_' + dataset_id + '.csv')

# %% [markdown]
# Download the "pre-processed_###.csv" file (where ### is the `dataset_id`) for future analysis. You can use this file in combination with the dataset ID to automatically filter your texts and reduce the processing time of your analyses.

# %% [markdown]
# ---
# ## Visualizing the Pre-Processed Data

# %%
# For displaying plots
# %matplotlib inline

# %%
# Group the data by publication year and the aggregated number of ids into a bar chart
df.groupby(['publicationYear'])['id'].agg('count').plot.bar(title='Documents by year', figsize=(20, 5), fontsize=12); 

# Read more about Pandas dataframe plotting here: 
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html

# %% [markdown]
# And now let's look at the total page numbers by year.

# %%
# Group the data by publication year and aggregated sum of the page counts into a bar chart

df.groupby(['publicationYear'])['pageCount'].agg('sum').plot.bar(title='Pages by decade', figsize=(20, 5), fontsize=12);
